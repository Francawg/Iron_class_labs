# %%
import pandas as pd 
import numpy as np
import re

# %% [markdown]
# #               Em que ano houve mais ataque de tubarão e em que região?
#
# informações importantes,  comparar quantidade de ataque no ano, ex de 01-01-2010 quantos ataques de tubarao houve e separar por regiao nos ultimos 8 anos, criar um top 5 regiões com ataque de tubarão
#
# *Organizar nomes das colunas ✔
#
# *Organizar os nomes dentro das colunas selecionadas, retirar missing values
#
# *Excluir colunas sem informações relevantes
#
# *Filtrar paises e estados
#
# *Ordenar valores da colunas ´sort_values()´

# %%
attack = pd.read_csv('C:/Users/wgfra/Aulas_ironhack/Aula_iron/Projeto_Shark_Attacks/attacks.csv', sep = ',', encoding='latin')

# %%
attack.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
attack = attack.drop(['href formula','href', 'Unnamed: 22','Unnamed: 23'],axis = 1)

# %%
attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'Case Number.1',
#        'Case Number.2', 'original order'],
#       dtype='object')

# %%
attack.columns = [col.lower().replace(' ','_').replace('.','_') for col in attack.columns]

# %%
attack = attack.rename({'sex_':'sex','species_':'species'}, axis=1)

# %%
attack.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal_(y/n)  \
# ...

# %% [markdown]
# #  Nan por 0 e verificar a exclusao das linhas abaixo de 6500

# %%
attack.loc[:,['case_number']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-155d6991da37> in <module>
# ----> 1 attack.loc[:,(['case_number']>2010)]
#
# TypeError: '>' not supported between instances of 'list' and 'int'
