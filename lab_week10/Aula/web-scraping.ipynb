# %%
import tqdm
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://jsonplaceholder.typicode.com/todos')
response.json()[0]
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %% [markdown]
# # The url to scrape

# %%
url = 'https://www.reuters.com/article/us-shazam-m-a-apple-eu/eu-clears-apples-purchase-of-shazam-idUSKCN1LM1TZ'

# %%
url
# Out:
# 'https://www.reuters.com/article/us-shazam-m-a-apple-eu/eu-clears-apples-purchase-of-shazam-idUSKCN1LM1TZ'

# %% [markdown]
# # Get the response

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-9-34c975fa6377> in <module>
# ----> 1 response.json()
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta name="robots" content="index, follow"/><meta name="twitter:site" content="@Reuters"/><meta name="twitter:creator" content="@Reuters"/><meta name="twitter:card" content="summary_large_image"/><meta name="msapplication-TileColor" content="#ff8000"/><meta name="msapplication-config" content="none"/><meta name="theme-color" content="#ffffff"/><meta property="article:publisher" content="https://www.facebook.com/Reuters"/><link rel="dns-prefetch" href="//s1.reutersmedia.net"/><link rel="dns-prefetch" href="//s2.reutersmedia.net"/><link rel="dns-prefetch" href="//s3.reutersmedia.net"/><link rel="dns-prefetch" href="//s4.reutersmedia.net"/><link rel="dns-prefetch" href="//static.reuters.com"/><link rel="dns-prefetch" href="//www.googletagservices.com"/><link rel="dns-prefetch" href="//www.googletagmanager.com"/><link rel="dns-prefetch" href="//www.google-analytics.com"/><link rel="dns-prefetch" href="//static.chartbeat.com"/><link rel="publisher" href="https://plus.google.com/+Reuters"/><link rel="shortcut icon" type="image/x-icon" href="/article/_next/static/images/favicon-9d0324f5d28e80e699a4e92617ab6f30.ico"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-16x16-e88bf4a1cca78d8c9db77bee8317e193.png" sizes="16x16"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-32x32-410cb61c32b1ef3ab7c27530775eda36.png" sizes="32x32"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-96x96-bda7fa3986384763dbb5a5486903d05b.png" sizes="96x96"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-128x128-9de93d21fd227b42b54c84e4ab242504.png" sizes="128x128"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-196x196-052cc719f1ac872e3544e51801338b46.png" sizes="196x196"/><meta name="description" content="The European Union approved Apple&#x27;s planned acquisition of British music discovery app Shazam on Thursday, saying an EU antitrust investigation showed it would not harm competition in the bloc."/><meta name="author" content="Reuters Staff"/><meta name="keywords" content="US,SHAZAM,M,A,APPLE,EU,Anti-competitive Behaviour / Price Fixing,EU Institutions,Company News,Arts / Culture / Entertainment,European Union,Europe,United Kingdom,Monopolies / Antitrust Issues,Mergers / Acquisitions / Takeovers,Music,Pictures,Picture available,Regulation,Entertainment Production (TRBC),Software (TRBC),Software &amp; IT Services (TRBC),International Trade,United States,Western Europe"/><meta name="news_keywords" content="US;SHAZAM;M;A;APPLE;EU;Anti-competitive Behaviour / Price Fixing;EU Institutions;Company News;Arts / Culture / Entertainment;European Union;Europe;United Kingdom;Monopolies / Antitrust Issues;Mergers / Acquisitions / Takeovers;Music;Pictures;Picture available;Regulation;Entertainment Production (TRBC);Software (TRBC);Software &amp; IT Services (TRBC);International Trade;United States;Western Europe"/><meta name="REVISION_DATE" content="2018-09-06T17:21:38Z"/><meta name="analyticsAttributes.articleDate" content="2018-09-06T17:21:38Z"/><meta name="analyticsAttributes.author" content="Reuters Staff"/><meta name="analyticsAttributes.canonicalUrl" content="https://www.reuters.com/article/us-shazam-m-a-apple-eu-idUSKCN1LM1TZ"/><meta name="analyticsAttributes.contentTitle" content="EU clears Apple&#x27;s purchase of Shazam"/><meta name="analyticsAttributes.edition" content="us"/><meta name="analyticsAttributes.keywords" content="US,SHAZAM,M,A,APPLE,EU,Anti-competitive Behaviour / Price Fixing,EU Institutions,Company News,Arts / Culture / Entertainment,European Union,Europe,United Kingdom,Monopolies / Antitrust Issues,Mergers / Acquisitions / Takeovers,Music,Pictures,Picture available,Regulation,En ...

# %%
type(response.content)
# Out:
# bytes

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta name="robots" content="index, follow"/><meta name="twitter:site" content="@Reuters"/><meta name="twitter:creator" content="@Reuters"/><meta name="twitter:card" content="summary_large_image"/><meta name="msapplication-TileColor" content="#ff8000"/><meta name="msapplication-config" content="none"/><meta name="theme-color" content="#ffffff"/><meta property="article:publisher" content="https://www.facebook.com/Reuters"/><link rel="dns-prefetch" href="//s1.reutersmedia.net"/><link rel="dns-prefetch" href="//s2.reutersmedia.net"/><link rel="dns-prefetch" href="//s3.reutersmedia.net"/><link rel="dns-prefetch" href="//s4.reutersmedia.net"/><link rel="dns-prefetch" href="//static.reuters.com"/><link rel="dns-prefetch" href="//www.googletagservices.com"/><link rel="dns-prefetch" href="//www.googletagmanager.com"/><link rel="dns-prefetch" href="//www.google-analytics.com"/><link rel="dns-prefetch" href="//static.chartbeat.com"/><link rel="publisher" href="https://plus.google.com/+Reuters"/><link rel="shortcut icon" type="image/x-icon" href="/article/_next/static/images/favicon-9d0324f5d28e80e699a4e92617ab6f30.ico"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-16x16-e88bf4a1cca78d8c9db77bee8317e193.png" sizes="16x16"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-32x32-410cb61c32b1ef3ab7c27530775eda36.png" sizes="32x32"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-96x96-bda7fa3986384763dbb5a5486903d05b.png" sizes="96x96"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-128x128-9de93d21fd227b42b54c84e4ab242504.png" sizes="128x128"/><link rel="icon" type="image/png" href="/article/_next/static/images/favicon-196x196-052cc719f1ac872e3544e51801338b46.png" sizes="196x196"/><meta name="description" content="The European Union approved Apple&#x27;s planned acquisition of British music discovery app Shazam on Thursday, saying an EU antitrust investigation showed it would not harm competition in the bloc."/><meta name="author" content="Reuters Staff"/><meta name="keywords" content="US,SHAZAM,M,A,APPLE,EU,Anti-competitive Behaviour / Price Fixing,EU Institutions,Company News,Arts / Culture / Entertainment,European Union,Europe,United Kingdom,Monopolies / Antitrust Issues,Mergers / Acquisitions / Takeovers,Music,Pictures,Picture available,Regulation,Entertainment Production (TRBC),Software (TRBC),Software &amp; IT Services (TRBC),International Trade,United States,Western Europe"/><meta name="news_keywords" content="US;SHAZAM;M;A;APPLE;EU;Anti-competitive Behaviour / Price Fixing;EU Institutions;Company News;Arts / Culture / Entertainment;European Union;Europe;United Kingdom;Monopolies / Antitrust Issues;Mergers / Acquisitions / Takeovers;Music;Pictures;Picture available;Regulation;Entertainment Production (TRBC);Software (TRBC);Software &amp; IT Services (TRBC);International Trade;United States;Western Europe"/><meta name="REVISION_DATE" content="2018-09-06T17:21:38Z"/><meta name="analyticsAttributes.articleDate" content="2018-09-06T17:21:38Z"/><meta name="analyticsAttributes.author" content="Reuters Staff"/><meta name="analyticsAttributes.canonicalUrl" content="https://www.reuters.com/article/us-shazam-m-a-apple-eu-idUSKCN1LM1TZ"/><meta name="analyticsAttributes.contentTitle" content="EU clears Apple&#x27;s purchase of Shazam"/><meta name="analyticsAttributes.edition" content="us"/><meta name="analyticsAttributes.keywords" content="US,SHAZAM,M,A,APPLE,EU,Anti-competitive Behaviour / Price Fixing,EU Institutions,Company News,Arts / Culture / Entertainment,European Union,Europe,United Kingdom,Monopolies / Antitrust Issues,Mergers / Acquisitions / Takeovers,Music,Pictures,Picture available,Regulation,Ent ...

# %% [markdown]
# # Get the html

# %%
html = response.content
html

# %% [markdown]
# `!pip install beautifulsoup4`

# %% [markdown]
# https://groups.google.com/forum/#!topic/beautifulsoup/rfyHGk0UjKU

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # Do the soup

# %%
soup = BeautifulSoup(html)
soup

# %%
soup.find_all('h1')

# %% [markdown]
# # With the soup, you'll be able to walk through the HTML tree.
# ## Looking for tag h1

# %%
soup.find_all('h1')

# %% [markdown]
# It returns a list of tags.

# %%
soup.find_all('h1')[0]

# %%
tag_h1 = soup.find('h1')
tag_h1

# %%
type(tag_h1)

# %%
tag_h1.text

# %%
url

# %%
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)
tag_h1 = soup.find('h1')
tag_h1.text

# %% [markdown]
# ## Looking for tag a

# %%
tag_a = soup.find_all('a')
tag_a

# %%
tag_a.text

# %%
tag_a.attrs['href']

# %%
from tqdm.auto import tqdm

# %%
tags = soup.find_all('a')

result = []
for tag in tqdm(tags):
    result.append(tag.attrs.get('href'))
    
result

# %%
soup.find_all('a')

# %% [markdown]
# Again, a list of tags

# %% [markdown]
# ## Searching Tags and specifying attributes

# %%
tag_span = soup.find('span', attrs={'class': 'trustBadgeUrl'})
tag_span

# %%
tag_span.find('a').text

# %%
tag_span.find('a').attrs['href']

# %% [markdown]
# ## Getting tag attributes

# %%
tag_a = tag_span.find('a')
tag_a

# %%
tag_a.attrs['href']

# %%
tag_a['href']

# %%
tag_a.get_attribute_list('href')

# %%
tag_a.get('href')

# %% [markdown]
# ## Searching for a list of tags

# %%
soup.find_all(['h1','p', 'a'])

# %% [markdown]
# ----

# %% [markdown]
# # Another example

# %% [markdown]
# <ol>
#     <li> request the url </li>
#     <li> get its html </li>
#     <li> convert to soup </li>
#     <li> being a soup, we can look for tags </li>
# </ol>

# %%
url = 'https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy'

# %%
response = requests.get(url)
response

# %%
html = response.content

# %%
soup = BeautifulSoup(html)
soup

# %% [markdown]
# ## Find the `table` tag whose `class=sortable wikitable`

# %%
table = soup.find('table', attrs={'class' : 'sortable wikitable'})

# %% [markdown]
# ## get the table header `<th>`

# %%
headers = [header.text.strip() for header in table.find_all('th')]

# %% [markdown]
# ## get the table data `<td>`

# %%
data = [data.text.strip() for data in table.find_all('td')]

# %%
nrows = int(len(data)/3)
ncols = 3

reshaped_array = np.array(data).reshape(nrows, ncols)

# %% [markdown]
# ## append results

# %%
pd.DataFrame(reshaped_array, columns=headers)

# %% [markdown]
# # Pandas to the rescue!

# %%
pd.read_html(url)[0]

# %%
pd.read_html(url, attrs={'class' : 'sortable wikitable'})

# %% [markdown]
# --------

# %% [markdown]
# # Some problems that may occur

# %% [markdown]
# ## Forbidden requests

# %% [markdown]
# Pandas can read_html from a string:

# %%
url = 'https://www.hltv.org/results'
pd.read_html(url)

# %%
pd.concat(pd.read_html(requests.get(url).content))

# %% [markdown]
# ## Headers to fake the browser you're using

# %%
url = 'https://www.hybrid-analysis.com/recent-submissions?filter=file&sort=^timestamp'
response = requests.get(url)
response

# %%
url = 'https://www.hybrid-analysis.com/recent-submissions?filter=file&sort=^timestamp'
response = requests.get(url)
soup = BeautifulSoup(response.content)
soup.find_all('h1')

# %%
requests.get('http://httpbin.org/headers').json()

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1)'}
requests.get('http://httpbin.org/headers', headers=headers).json()

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content)
soup.find_all('h1')
